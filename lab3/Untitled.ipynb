# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
from scipy.stats import ttest_ind
table = [
    [35, 15],
    [25, 25]
]
print("\nObservation Table")
print(table)
# Out:
# Observation Table
# [[35, 15], [25, 25]]

# %%
stat, p, dof, expected = chi2_contingency(table)

# %%
chi2_contingency(table)
# Out:
# Chi2ContingencyResult(statistic=3.375, pvalue=0.06619257972219346, dof=1, expected_freq=array([[30., 20.],
#        [30., 20.]]))

# %%
print("\nExpectation Table")
print(expected)
print("\nThe Critical Value")
print(critical)

print("Statistical Value")
print(stat)
# Out:
# Expectation Table
# [[30. 20.]
#  [30. 20.]]
#
# The Critical Value
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 print(expected)
#       3 print("\nThe Critical Value")
# ----> 4 print(critical)
#       6 print("Statistical Value")
#       7 print(stat)
#
# NameError: name 'critical' is not defined
